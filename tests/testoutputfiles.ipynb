# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#auxp_in array from smearing_T.py
A = np.loadtxt('auxp_in.dat',dtype=complex)
plt.plot(np.real(A))
plt.show()
plt.plot(np.imag(A))
plt.show()
