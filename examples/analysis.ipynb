# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = np.loadtxt("example1/output/conductance_bulk.dat")
plt.plot(T[:, 0], T[:, 1], label="eg 1")
plt.title("Example 1: Conductance (Bulk)")
plt.show()
T = np.loadtxt("example2/output/conductance_bulk.dat")
plt.plot(T[:, 0], T[:, 1], label="eg 2")
plt.title("Example 2: Conductance (Bulk)")
plt.show()
T = np.loadtxt("example2/output/conductance_lcr.dat")
plt.plot(T[:, 0], T[:, 1], label="eg 2")
plt.title("Example 2: Conductance (LCR)")
plt.show()

# %%
dos = np.loadtxt("example1/output/doscond_bulk.dat")
plt.plot(dos[:, 0], dos[:, 1], label="eg 1")
plt.title("Example 1: DOS")
plt.show()
dos = np.loadtxt("example2/output/doscond_bulk.dat")
plt.plot(dos[:, 0], dos[:, 1], label="eg 2")
plt.title("Example 2: DOS")
plt.show()
dos = np.loadtxt("example2/output/doscond_lcr.dat")
plt.plot(dos[:, 0], dos[:, 1], label="eg 2")
plt.title("Example 2: DOS (LCR)")
plt.show()
