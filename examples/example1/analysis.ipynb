# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dos = np.loadtxt("output/conductance.dat")
plt.plot(dos[:, 0], dos[:, 1], label="Conductance")

# %%
dos = np.loadtxt("output/doscond.dat")
plt.plot(dos[:, 0], dos[:, 1], label="dos")
